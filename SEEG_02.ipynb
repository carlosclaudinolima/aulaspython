# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosclaudinolima/aulaspython/blob/main/SEEG_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = '/content/sample_data/emissoes_gases 01.csv'

# %%
pd.read_csv(url)
# Out:
# <ipython-input-6-7e3ce7e6e77c>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(url)
#        Unnamed: 0                     Nível 1 - Setor              Nível 2  \
# 0               0               Processos Industriais    Indústria Química
# 1               1               Processos Industriais    Indústria Química
# 2               2               Processos Industriais    Indústria Química
# 3               3               Processos Industriais    Indústria Química
# 4               4               Processos Industriais    Indústria Química
# ...           ...                                 ...                  ...
# 94743      103241  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 94744      103242  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 94745      103243  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 94746      103244  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 94747      103245  Mudança de Uso da Terra e Floresta  Resíduos Florestais
#
#                          Nível 3 Nível 4       Nível 5 Nível 6  \
# 0                Produção de ABS     NaN           NaN     NaN
# 1      Produção de Ácido Adípico     NaN           NaN     NaN
# 2      Produção de Ácido Adípico     NaN           NaN     NaN
# 3      Produção de Ácido Adípico     NaN           NaN     NaN
# 4      Produção de Ácido Adípico     NaN           NaN     NaN
# ...                          ...     ...           ...     ...
# 94743                   Pantanal     NaN  Desmatamento     NaN
# 94744                   Pantanal     NaN  Desmatamento     NaN
# 94745                   Pantanal     NaN  Desmatamento     NaN
# 94746                   Pantanal     NaN  Desmatamento     NaN
# 94747                   Pantanal     NaN  Desmatamento     NaN
#
#                     Gás Estado Atividade Econômica  ...           2012  \
# 0             COVNM (t)     SP           OUTRA_IND  ...     897.600000
# 1               N2O (t)     SP           OUTRA_IND  ...     130.000000
# 2                CO (t)     SP           OUTRA_IND  ...    1380.576000
# 3               NOx (t)     SP           OUTRA_IND  ...     431.430000
# 4      CO2e (t) GWP-AR2     SP           OUTRA_IND  ...   40300.000000
# ...                 ...    ...                 ...  ...            ...
# 94743  CO2e (t) GWP-AR5     MS             AGROPEC  ...  436935.000000
# 94744  CO2e (t) GWP-AR6     MT             AGROPEC  ...  126806.000000
# 94745  CO2e (t) GWP-AR6     MS             AGROPEC  ...  439524.000000
# 94746           N2O (t)     MT             AGROPEC  ...     108.441090
# 94747           N2O (t)     MS             AGROPEC  ...     463.968255
#
#                 2013           2014           2015           2016  \
# 0         897.600000     897.600000     897.600000     897.600000
# 1         130.000000     130.000000     130.000000     130.000000
# 2        1380.576000    1380.576000    1380.576000    1380.576000
# 3         431.430000     431.430000     431.430000     431.430000
# 4       40300.000000   40300.000000   40300.000000   40300.000000
# ...              ...            ...            ...            ...
# 94743  500067.000000  440030.000000  365272.000000  438422.000000
# 94744  127558.000000  193758.000000  164585.000000  234509.000000
# 94745  502908.000000  442493.000000  367116.000000  440798.000000
# 94746     109.811199     166.680103     141.442361     201.556097
# 94747     517.078826     450.849218     352.160440     440.753215
#
#                 2017           2018        2019        2020         2021
# 0         897.600000     897.600000     897.600     897.600      897.600
# 1         130.000000     130.000000     130.000     130.000      130.000
# 2        1380.576000    1380.576000    1380.576    1380.576     1380.576
# 3         431.430000     431.430000     431.430     431.430      431.430
# 4       40300.000000   40300.000000   40300.000   40300.000    40300.000
# ...              ...            ...         ...         ...          ...
# 94743  391113.000000  411738.000000  437039.000  871393.000  1004191.000
# 94744  190412.000000  162919.000000  186091.000  368149.000   443120.000
# 94745  393101.000000  413749.000000  439526.000  876637.000  1009968.000
# 94746     162.932751     137.219684     158.000     314.000      479.000
# 94747     378.038216     388.896998     452.000     935.000     1047.000
#
# [94748 rows x 63 columns]
