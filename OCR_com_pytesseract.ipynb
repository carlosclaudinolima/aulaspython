# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosclaudinolima/aulaspython/blob/main/OCR_com_pytesseract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Pillow

# %%
# !pip install pytesseract

# %%
from PIL import Image

# %%
import pytesseract

# %%
image_path =  '/content/drive/MyDrive/On-image-4-21-1-1024x666.jpg'

# %%
img = Image.open(image_path)

# %%
ocr_text = pytesseract.image_to_pdf_or_hocr(img, extension='pdf')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x666>
